# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## For pancancer

# %%
seeds = list(range(9))
#Generating the x-coordinates at which to evaluate the interpolated values.
all_fpr = pd.Series()
print(type(all_fpr))
all_tpr = pd.DataFrame()
for i in seeds:
    csv = pd.read_csv("../temp/pr_dnnwc"+str(i)+"Fold.csv", header = 0)
    all_fpr = pd.concat([all_fpr, csv['recall']], ignore_index = True, sort = True)
all_fpr = pd.unique(all_fpr)
#Interpolating values of X-coordinates for 10 groups 'tpr' data. 
for i in seeds:
    csv = pd.read_csv("../temp/pr_dnnwc"+str(i)+"Fold.csv", header = 0)
    csv = csv.sort_values(by = 'recall', ignore_index = True)
    all_tpr['seed'+str(i)] = np.interp(all_fpr, csv['recall'], csv['precision'])
# Out:
# <class 'pandas.core.series.Series'>
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_14048\3267871842.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   all_fpr = pd.Series()

# %%
all_tpr.shape
# Out:
# (301, 9)

# %%
all_tpr['mean'] = all_tpr.mean(axis = 1)
all_tpr['std'] = all_tpr.std(axis =  1)

# %%
all_tpr['all_recall'] = all_fpr

# %%
all_tpr['lower'] = all_tpr['mean'].sub(all_tpr['std'])
all_tpr['upper'] = all_tpr['mean'].add(all_tpr['std'])

# %%
all_tpr.to_csv("../temp/DNNinterp4repeatedPR_pancancer.csv", header = True, index = True)

# %%
all_tpr.iloc[100:105, 0:15]
# Out:
#         seed0     seed1     seed2     seed3     seed4     seed5     seed6  \
# 100  0.757576  0.803213  0.772201  0.729927  0.803213  0.760456  0.732601
# 101  0.756654  0.805668  0.774319  0.737037  0.802419  0.762452  0.737037
# 102  0.755725  0.804878  0.779528  0.738806  0.801619  0.761538  0.755725
# 103  0.763566  0.804082  0.778656  0.737828  0.800813  0.760618  0.754789
# 104  0.768627  0.803279  0.777778  0.745247  0.800000  0.762646  0.756757
#
#         seed7     seed8      mean       std  all_recall     lower     upper
# 100  0.809717  0.751880  0.768976  0.028592    0.666667  0.740384  0.797567
# 101  0.818930  0.753788  0.772034  0.028616    0.663333  0.743418  0.800650
# 102  0.818182  0.752852  0.774317  0.026262    0.660000  0.748055  0.800579
# 103  0.817427  0.751908  0.774410  0.025784    0.656667  0.748625  0.800194
# 104  0.816667  0.756757  0.776417  0.023320    0.653333  0.753097  0.799738

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(csv['recall'], csv['precision'], color = 'green')
ax.scatter(all_fpr, all_tpr['seed0'], c='red', marker='+', linewidths = 1.0)
plt.savefig("dnninterp0PR_pancancer.pdf", dpi=300)

# %% [markdown]
# ## For breast cancer

# %%
seeds = list(range(9))
#Generating the x-coordinates at which to evaluate the interpolated values.
all_fpr = pd.Series()
print(type(all_fpr))
all_tpr = pd.DataFrame()
for i in seeds:
    csv = pd.read_csv("../temp/breast_pr_dnnwc"+str(i)+"Fold.csv", header = 0)
    all_fpr = pd.concat([all_fpr, csv['recall']], ignore_index = True, sort = True)
all_fpr = pd.unique(all_fpr)
#Interpolating values of X-coordinates for 10 groups 'tpr' data. 
for i in seeds:
    csv = pd.read_csv("../temp/breast_pr_dnnwc"+str(i)+"Fold.csv", header = 0)
    csv = csv.sort_values(by = 'recall', ignore_index = True)
    all_tpr['seed'+str(i)] = np.interp(all_fpr, csv['recall'], csv['precision'])
# Out:
# <class 'pandas.core.series.Series'>
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_3384\3946248990.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   all_fpr = pd.Series()

# %%
all_tpr['mean'] = all_tpr.mean(axis = 1)
all_tpr['std'] = all_tpr.std(axis =  1)
all_tpr['all_recall'] = all_fpr
all_tpr['lower'] = all_tpr['mean'].sub(all_tpr['std'])
all_tpr['upper'] = all_tpr['mean'].add(all_tpr['std'])

# %%
all_tpr.to_csv("../temp/DNNinterp4repeatedPR_breast.csv", header = True, index = True)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(csv['recall'], csv['precision'], color = 'green')
ax.scatter(all_fpr, all_tpr['seed0'], c='red', marker='+', linewidths = 1.0)
plt.savefig("dnninterp0PR_breast.pdf", dpi=300)

# %% [markdown]
# ## For colon cancer

# %%
seeds = list(range(9))
#Generating the x-coordinates at which to evaluate the interpolated values.
all_fpr = pd.Series(dtype=)
print(type(all_fpr))
all_tpr = pd.DataFrame()
for i in seeds:
    csv = pd.read_csv("../temp/pr_dnnwc_colon"+str(i)+"Fold.csv", header = 0)
    all_fpr = pd.concat([all_fpr, csv['recall']], ignore_index = True, sort = True)
all_fpr = pd.unique(all_fpr)
#Interpolating values of X-coordinates for 10 groups 'tpr' data. 
for i in seeds:
    csv = pd.read_csv("../temp/pr_dnnwc_colon"+str(i)+"Fold.csv", header = 0)
    csv = csv.sort_values(by = 'recall', ignore_index = True)
    all_tpr['seed'+str(i)] = np.interp(all_fpr, csv['recall'], csv['precision'])
# Out:
# <class 'pandas.core.series.Series'>
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_10944\1782450212.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   all_fpr = pd.Series()

# %%
all_tpr['mean'] = all_tpr.mean(axis = 1)
all_tpr['std'] = all_tpr.std(axis =  1)
all_tpr['all_recall'] = all_fpr
all_tpr['lower'] = all_tpr['mean'].sub(all_tpr['std'])
all_tpr['upper'] = all_tpr['mean'].add(all_tpr['std'])

# %%
all_tpr.to_csv("../temp/DNNinterp4repeatedPR_colon.csv", header = True, index = True)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(csv['recall'], csv['precision'], color = 'green')
ax.scatter(all_fpr, all_tpr['seed0'], c='red', marker='+', linewidths = 1.0)
plt.savefig("dnninterp0PR_colon.pdf", dpi=300)

# %% [markdown]
# ## For pancreas cancer

# %%
seeds = list(range(9))
#Generating the x-coordinates at which to evaluate the interpolated values.
all_fpr = pd.Series()
print(type(all_fpr))
all_tpr = pd.DataFrame()
for i in seeds:
    csv = pd.read_csv("../temp/pr_dnnwc_pancreas"+str(i)+"Fold.csv", header = 0)
    all_fpr = pd.concat([all_fpr, csv['recall']], ignore_index = True, sort = True)
all_fpr = pd.unique(all_fpr)
#Interpolating values of X-coordinates for 10 groups 'tpr' data. 
for i in seeds:
    csv = pd.read_csv("../temp/pr_dnnwc_pancreas"+str(i)+"Fold.csv", header = 0)
    csv = csv.sort_values(by = 'recall', ignore_index = True)
    all_tpr['seed'+str(i)] = np.interp(all_fpr, csv['recall'], csv['precision'])
# Out:
# <class 'pandas.core.series.Series'>
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_2212\4240018801.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   all_fpr = pd.Series()

# %%
all_tpr['mean'] = all_tpr.mean(axis = 1)
all_tpr['std'] = all_tpr.std(axis =  1)
all_tpr['all_recall'] = all_fpr
all_tpr['lower'] = all_tpr['mean'].sub(all_tpr['std'])
all_tpr['upper'] = all_tpr['mean'].add(all_tpr['std'])

# %%
all_tpr.to_csv("../temp/DNNinterp4repeatedPR_pancreas.csv", header = True, index = True)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(csv['recall'], csv['precision'], color = 'green')
ax.scatter(all_fpr, all_tpr['seed0'], c='red', marker='+', linewidths = 1.0)
plt.savefig("dnninterp0PR_pancreas.pdf", dpi=300)

# %% [markdown]
# ## For pancancer with MACCSKeys representation

# %%
seeds = list(range(9))
#Generating the x-coordinates at which to evaluate the interpolated values.
all_fpr = pd.Series(dtype = 'float32')
print(type(all_fpr))
all_tpr = pd.DataFrame()
for i in seeds:
    csv = pd.read_csv("../temp/pr_dnnwc_macc_normalize"+str(i)+"Fold.csv", header = 0)
    all_fpr = pd.concat([all_fpr, csv['recall']], ignore_index = True, sort = True)
all_fpr = pd.unique(all_fpr)
#Interpolating values of X-coordinates for 10 groups 'tpr' data. 
for i in seeds:
    csv = pd.read_csv("../temp/pr_dnnwc_macc_normalize"+str(i)+"Fold.csv", header = 0)
    csv = csv.sort_values(by = 'recall', ignore_index = True)
    all_tpr['seed'+str(i)] = np.interp(all_fpr, csv['recall'], csv['precision'])
# Out:
# <class 'pandas.core.series.Series'>

# %%
all_tpr['mean'] = all_tpr.mean(axis = 1)
all_tpr['std'] = all_tpr.std(axis =  1)
all_tpr['all_recall'] = all_fpr
all_tpr['lower'] = all_tpr['mean'].sub(all_tpr['std'])
all_tpr['upper'] = all_tpr['mean'].add(all_tpr['std'])

# %%
all_tpr.to_csv("../temp/DNNinterp4repeatedPR_macc_normalize.csv", header = True, index = True)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(csv['recall'], csv['precision'], color = 'green')
ax.scatter(all_fpr, all_tpr['seed0'], c='red', marker='+', linewidths = 1.0)
plt.savefig("dnninterp0PR_macc_normalize.pdf", dpi=300)

# %% [markdown]
# ## For pancancer model on MACCS Keys train data.

# %%
seeds = list(range(9))
#Generating the x-coordinates at which to evaluate the interpolated values.
all_fpr = pd.Series(dtype = 'float32')
print(type(all_fpr))
all_tpr = pd.DataFrame()
for i in seeds:
    csv = pd.read_csv("../temp/MACCSKeys/pr_dnnwc" + str(i) + "macc_pytorch.csv", header = 0)
    all_fpr = pd.concat([all_fpr, csv['recall']], ignore_index = True, sort = True)
all_fpr = pd.unique(all_fpr)
#Interpolating values of X-coordinates for 10 groups 'tpr' data. 
for i in seeds:
    csv = pd.read_csv("../temp/MACCSKeys/pr_dnnwc" + str(i) + "macc_pytorch.csv", header = 0)
    csv = csv.sort_values(by = 'recall', ignore_index = True)
    all_tpr['seed'+str(i)] = np.interp(all_fpr, csv['recall'], csv['precision'])
# Out:
# <class 'pandas.core.series.Series'>

# %%
all_tpr['mean'] = all_tpr.mean(axis = 1)
all_tpr['std'] = all_tpr.std(axis =  1)
all_tpr['all_recall'] = all_fpr
all_tpr['lower'] = all_tpr['mean'].sub(all_tpr['std'])
all_tpr['upper'] = all_tpr['mean'].add(all_tpr['std'])

# %%
all_tpr.to_csv("../temp/MACCSKeys/DNNinterp4repeatedPR_pytorch_macc.csv", header = True, index = True)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(csv['recall'], csv['precision'], color = 'green')
ax.scatter(all_fpr, all_tpr['seed0'], c='red', marker='+', linewidths = 1.0)
plt.savefig("dnninterp0PR_pytorch_macc.pdf", dpi=300)

# %% [markdown]
# ## For pancancer model on MACCS Keys test data.

# %%
seeds = list(range(9))
#Generating the x-coordinates at which to evaluate the interpolated values.
all_fpr = pd.Series(dtype = 'float32')
print(type(all_fpr))
all_tpr = pd.DataFrame()
for i in seeds:
    csv = pd.read_csv("../temp/MACCSKeys/pr_dnnwc" + str(i) + "macc_pytorch_test.csv", header = 0)
    all_fpr = pd.concat([all_fpr, csv['recall']], ignore_index = True, sort = True)
all_fpr = pd.unique(all_fpr)
#Interpolating values of X-coordinates for 10 groups 'tpr' data. 
for i in seeds:
    csv = pd.read_csv("../temp/MACCSKeys/pr_dnnwc" + str(i) + "macc_pytorch_test.csv", header = 0)
    csv = csv.sort_values(by = 'recall', ignore_index = True)
    all_tpr['seed'+str(i)] = np.interp(all_fpr, csv['recall'], csv['precision'])
# Out:
# <class 'pandas.core.series.Series'>

# %%
all_tpr['mean'] = all_tpr.mean(axis = 1)
all_tpr['std'] = all_tpr.std(axis =  1)
all_tpr['all_recall'] = all_fpr
all_tpr['lower'] = all_tpr['mean'].sub(all_tpr['std'])
all_tpr['upper'] = all_tpr['mean'].add(all_tpr['std'])

# %%
all_tpr.to_csv("../temp/MACCSKeys/DNNinterp4repeatedPR_pytorch_macc_test.csv", header = True, index = True)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(csv['recall'], csv['precision'], color = 'green')
ax.scatter(all_fpr, all_tpr['seed0'], c='red', marker='+', linewidths = 1.0)
plt.savefig("dnninterp0PR_pytorch_macc_test.pdf", dpi=300)

# %% [markdown]
# ## For pancancer model on train data.

# %%
seeds = list(range(9))
#Generating the x-coordinates at which to evaluate the interpolated values.
all_fpr = pd.Series(dtype = 'float32')
print(type(all_fpr))
all_tpr = pd.DataFrame()
for i in seeds:
    csv = pd.read_csv("../temp/pytorch/pr_dnnwc" + str(i) + "train_pytorch.csv", header = 0)
    all_fpr = pd.concat([all_fpr, csv['recall']], ignore_index = True, sort = True)
all_fpr = pd.unique(all_fpr)
#Interpolating values of X-coordinates for 10 groups 'tpr' data. 
for i in seeds:
    csv = pd.read_csv("../temp/pytorch/pr_dnnwc" + str(i) + "train_pytorch.csv", header = 0)
    csv = csv.sort_values(by = 'recall', ignore_index = True)
    all_tpr['seed'+str(i)] = np.interp(all_fpr, csv['recall'], csv['precision'])
# Out:
# <class 'pandas.core.series.Series'>

# %%
all_tpr['mean'] = all_tpr.mean(axis = 1)
all_tpr['std'] = all_tpr.std(axis =  1)
all_tpr['all_recall'] = all_fpr
all_tpr['lower'] = all_tpr['mean'].sub(all_tpr['std'])
all_tpr['upper'] = all_tpr['mean'].add(all_tpr['std'])

# %%
all_tpr.to_csv("../temp/pytorch/DNNinterp4repeatedPR_pytorch_train.csv", header = True, index = True)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(csv['recall'], csv['precision'], color = 'green')
ax.scatter(all_fpr, all_tpr['seed0'], c='red', marker='+', linewidths = 1.0)
plt.savefig("dnninterp0PR_pytorch_train.pdf", dpi=300)

# %% [markdown]
# ## For pancancer model on test data.

# %%
seeds = list(range(9))
#Generating the x-coordinates at which to evaluate the interpolated values.
all_fpr = pd.Series(dtype = 'float32')
print(type(all_fpr))
all_tpr = pd.DataFrame()
for i in seeds:
    csv = pd.read_csv("../temp/pytorch/pr_dnnwc" + str(i) + "Fold_pytorch.csv", header = 0)
    all_fpr = pd.concat([all_fpr, csv['recall']], ignore_index = True, sort = True)
all_fpr = pd.unique(all_fpr)
#Interpolating values of X-coordinates for 10 groups 'tpr' data. 
for i in seeds:
    csv = pd.read_csv("../temp/pytorch/pr_dnnwc" + str(i) + "Fold_pytorch.csv", header = 0)
    csv = csv.sort_values(by = 'recall', ignore_index = True)
    all_tpr['seed'+str(i)] = np.interp(all_fpr, csv['recall'], csv['precision'])
# Out:
# <class 'pandas.core.series.Series'>

# %%
all_tpr['mean'] = all_tpr.mean(axis = 1)
all_tpr['std'] = all_tpr.std(axis =  1)
all_tpr['all_recall'] = all_fpr
all_tpr['lower'] = all_tpr['mean'].sub(all_tpr['std'])
all_tpr['upper'] = all_tpr['mean'].add(all_tpr['std'])

# %%
all_tpr.to_csv("../temp/pytorch/DNNinterp4repeatedPR_pytorch_test.csv", header = True, index = True)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(csv['recall'], csv['precision'], color = 'green')
ax.scatter(all_fpr, all_tpr['seed0'], c='red', marker='+', linewidths = 1.0)
plt.savefig("dnninterp0PR_pytorch_test.pdf", dpi=300)
