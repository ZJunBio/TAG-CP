# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Apr 11 13:42:27 2023

@author: Zhang Jun
"""

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data/Originalscreen_Alltissues_fitteddata.csv", header = 0, quotechar = '"')
# Out:
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\2805218171.py:1: DtypeWarning: Columns (6,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("data/Originalscreen_Alltissues_fitteddata.csv", header = 0, quotechar = '"')

# %%
synergy_data = data[data["Synergy"] == True]
anta_data = data[data["Synergy"] == False]

# %%
#Get unique "combination-cell line" pairs.
synergy_pair = synergy_data[np.logical_not(synergy_data.duplicated(subset = ["COMBI_ID", "CELL_LINE_NAME"], keep = 'first'))]
anta_pair = anta_data[np.logical_not(anta_data.duplicated(subset = ["COMBI_ID", "CELL_LINE_NAME"], keep = 'first'))]
print(len(synergy_pair), len(anta_pair))
# Out:
# 6158 106842

# %%
#Get "combination-cell line" pairs with fuzzy labels.
seta = synergy_pair["COMBI_ID"] + "+" + synergy_pair["CELL_LINE_NAME"]
setb = anta_pair["COMBI_ID"] + "+" +anta_pair["CELL_LINE_NAME"]
fuzzy = set(seta) & set(setb)
print(len(fuzzy))
# Out:
# 4741

# %%
#Label fuzzy pairs.
for e in fuzzy:
    combi_id = e.split("+")[0]
    cell = e.split("+")[1]
    
    measures_df = data[np.logical_and(data["COMBI_ID"] == combi_id, data["CELL_LINE_NAME"] == cell)]

    if len(pd.unique(measures_df["ANCHOR_CONC"])) == 1:
        if len(measures_df[measures_df["Synergy"] == True]) >= len(measures_df) / 2:
            data.iloc[measures_df.index, data.columns.get_loc('Synergy')] = True
        else:
            data.iloc[measures_df.index, data.columns.get_loc('Synergy')] = False
    #elif len(pd.unique(measures_df["ANCHOR_CONC"])) > 1:
     #   data.iloc[measures_df.index, data.columns.get_loc('Synergy')] = True

# %%
combs = pd.DataFrame(columns = data.columns)
for e in fuzzy:
    combi_id = e.split("+")[0]
    cell = e.split("+")[1]
    
    measures_df = data[np.logical_and(data["COMBI_ID"] == combi_id, data["CELL_LINE_NAME"] == cell)]
    combs = pd.concat((combs, measures_df), axis = 0)
    
combs.to_csv("./data/pairwith2labels.csv", header = True, index = True, quotechar = '"')
# Out:
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# ...
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# C:\Users\Zhang Jun\AppData\Local\Temp\ipykernel_13996\459385075.py:7: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   combs = pd.concat((combs, measures_df), axis = 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       3     combi_id = e.split("+")[0]
#       4     cell = e.split("+")[1]
# ----> 6     measures_df = data[np.logical_and(data["COMBI_ID"] == combi_id, data["CELL_LINE_NAME"] == cell)]
#       7     combs = pd.concat((combs, measures_df), axis = 0)
#       9 combs.to_csv("./data/pairwith2labels.csv", header = True, index = True)
#
# File D:\Bio_tools\conda\envs\most_tf\lib\site-packages\pandas\core\generic.py:2113, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2109 @final
#    2110 def __array_ufunc__(
#    2111     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2112 ):
# -> 2113     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File D:\Bio_tools\conda\envs\most_tf\lib\site-packages\pandas\core\arraylike.py:314, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     311             axes[i] = ax1.union(ax2)
#     313     reconstruct_axes = dict(zip(self._AXIS_ORDERS, axes))
# --> 314     inputs = tuple(
#     315         x.reindex(**reconstruct_axes) if issubclass(t, NDFrame) else x
#     316         for x, t in zip(inputs, types)
#     317     )
#     318 else:
#     319     reconstruct_axes = dict(zip(self._AXIS_ORDERS, self.axes))
#
# File D:\Bio_tools\conda\envs\most_tf\lib\site-packages\pandas\core\arraylike.py:315, in <genexpr>(.0)
#     311             axes[i] = ax1.union(ax2)
#     313     reconstruct_axes = dict(zip(self._AXIS_ORDERS, axes))
#     314     inputs = tuple(
# --> 315         x.reindex(**reconstruct_axes) if issubclass(t, NDFrame) else x
#     316         for x, t in zip(inputs, types)
#     317     )
#     318 else:
#     319     reconstruct_axes = dict(zip(self._AXIS_ORDERS, self.axes))
#
# File D:\Bio_tools\conda\envs\most_tf\lib\site-packages\pandas\core\series.py:5094, in Series.reindex(self, *args, **kwargs)
#    5090         raise TypeError(
#    5091             "'index' passed as both positional and keyword argument"
#    5092         )
#    5093     kwargs.update({"index": index})
# -> 5094 return super().reindex(**kwargs)
#
# File D:\Bio_tools\conda\envs\most_tf\lib\site-packages\pandas\core\generic.py:5282, in NDFrame.reindex(self, *args, **kwargs)
#    5275 # if all axes that are requested to reindex are equal, then only copy
#    5276 # if indicated must have index names equal here as well as values
#    5277 if all(
#    5278     self._get_axis(axis).identical(ax)
#    5279     for axis, ax in axes.items()
#    5280     if ax is not None
#    5281 ):
# -> 5282     return self.copy(deep=copy)
#    5284 # check if we are a multi reindex
#    5285 if self._needs_reindex_multi(axes, method, level):
#
# File D:\Bio_tools\conda\envs\most_tf\lib\site-packages\pandas\core\generic.py:6368, in NDFrame.copy(self, deep)
#    6258 @final
#    6259 def copy(self: NDFrameT, deep: bool_t | None = True) -> NDFrameT:
#    6260     """
#    6261     Make a copy of this object's indices and data.
#    6262
#    (...)
#    6366     dtype: object
#    6367     """
# -> 6368     data = self._mgr.copy(deep=deep)
#    6369     self._clear_item_cache()
#    6370     return self._constructor(data).__finalize__(self, method="copy")
#
# File D:\Bio_tools\conda\envs\most_tf\lib\site-packages\pandas\core\internals\managers.py:651, in BaseBlockManager.copy(self, deep)
#     648 else:
#     649     new_axes = list(self.axes)
# --> 651 res = self.apply("copy", deep=deep)
#     652 new_refs: list[weakref.ref | None] | None
#     653 if deep:
#
# File D:\Bio_tools\conda\envs\most_tf\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File D:\Bio_tools\conda\envs\most_tf\lib\site-packages\pandas\core\internals\blocks.py:549, in Block.copy(self, deep)
#     547 values = self.values
#     548 if deep:
# --> 549     values = values.copy()
#     550 return type(self)(values, placement=self._mgr_locs, ndim=self.ndim)
#
# KeyboardInterrupt:

# %%
b

# %%
#Label fuzzy pairs.
for e in fuzzy:
    combi_id = e.split("+")[0]
    cell = e.split("+")[1]
    
    measures_df = data[np.logical_and(data["COMBI_ID"] == combi_id, data["CELL_LINE_NAME"] == cell)]

    if len(measures_df[measures_df["Synergy"] == True]) >= (len(measures_df) / 2):
        data.iloc[measures_df.index, data.columns.get_loc('Synergy')] = True
    else:
        data.iloc[measures_df.index, data.columns.get_loc('Synergy')] = False
    #elif len(pd.unique(measures_df["ANCHOR_CONC"])) > 1:
     #   data.iloc[measures_df.index, data.columns.get_loc('Synergy')] = True

# %%
data.to_csv("./data/data_no_fuzzy.csv", header = True, index = False, quotechar = '"')
synergy_pair.to_csv("./data/synergy_pair_dnf.csv", header = True, index = False, quotechar = '"')
anta_pair.to_csv("./data/anta_pair_dnf.csv", header = True, index = False, quotechar = '"')
